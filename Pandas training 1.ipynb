# %%
import pandas as pd
import fix_yahoo_finance as yf
# Writing to an excel  
# sheet using Python 
import xlwt 
from xlwt import Workbook 
# Workbook is created 
wb = Workbook() 
# add_sheet is used to create sheet. 
sheet1 = wb.add_sheet('Sheet 1')

# %%
start = '2004-01-01'
end = '2019-05-01'
tickers=['EURUSD=X']

# %%
eurusd = yf.download(tickers[0], start=start, end=end)
# Out:
# [*********************100%***********************]  1 of 1 downloaded

# %%
eurusd.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
es.tail()
# Out:
#               Open    High     Low   Close  Adj Close  Volume
# Date
# 2019-04-24  1.1224  1.1225  1.1183  1.1224     1.1224       0
# 2019-04-25  1.1157  1.1164  1.1122  1.1153     1.1153       0
# 2019-04-26  1.1137  1.1173  1.1123  1.1137     1.1137       0
# 2019-04-29  1.1149  1.1170  1.1146  1.1150     1.1150       0
# 2019-04-30  1.1184  1.1230  1.1177  1.1185     1.1185       0

# %%
es.describe()
# Out:
#               Open         High          Low        Close    Adj Close  Volume
# count  3972.000000  3972.000000  3972.000000  3972.000000  3972.000000  3972.0
# mean      1.274091     1.279074     1.268570     1.274097     1.274097     0.0
# std       0.118802     0.119392     0.119847     0.118800     0.118800     0.0
# min       1.039400     1.042000     0.072900     1.039000     1.039000     0.0
# 25%       1.181150     1.184800     1.177300     1.181375     1.181375     0.0
# 50%       1.280900     1.286450     1.274700     1.280900     1.280900     0.0
# 75%       1.354925     1.360025     1.350200     1.354725     1.354725     0.0
# max       1.598200     1.602800     1.587400     1.598800     1.598800     0.0

# %%
es.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3972 entries, 2003-12-31 to 2019-04-30
# Data columns (total 6 columns):
# Open         3972 non-null float64
# High         3972 non-null float64
# Low          3972 non-null float64
# Close        3972 non-null float64
# Adj Close    3972 non-null float64
# Volume       3972 non-null int64
# dtypes: float64(5), int64(1)
# memory usage: 217.2 KB

# %%
es.shape
# Out:
# (3972, 6)

# %%
es.index
# Out:
# DatetimeIndex(['2003-12-31', '2004-01-01', '2004-01-02', '2004-01-05',
#                '2004-01-06', '2004-01-07', '2004-01-08', '2004-01-09',
#                '2004-01-12', '2004-01-13',
#                ...
#                '2019-04-17', '2019-04-18', '2019-04-19', '2019-04-22',
#                '2019-04-23', '2019-04-24', '2019-04-25', '2019-04-26',
#                '2019-04-29', '2019-04-30'],
#               dtype='datetime64[ns]', name='Date', length=3972, freq=None)

# %%
es.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
es["Close"]
# Out:
# Date
# 2003-12-31    1.2590
# 2004-01-01    1.2582
# 2004-01-02    1.2582
# 2004-01-05    1.2687
# 2004-01-06    1.2721
# 2004-01-07    1.2641
# 2004-01-08    1.2775
# 2004-01-09    1.2859
# 2004-01-12    1.2741
# 2004-01-13    1.2786
# 2004-01-14    1.2651
# 2004-01-15    1.2601
# 2004-01-16    1.2398
# 2004-01-19    1.2354
# 2004-01-20    1.2589
# 2004-01-21    1.2659
# 2004-01-22    1.2725
# 2004-01-23    1.2583
# 2004-01-26    1.2488
# 2004-01-27    1.2637
# 2004-01-28    1.2442
# 2004-01-29    1.2410
# 2004-01-30    1.2468
# 2019-04-22  1.1245  1.1264  1.1237  1.1245     1.1245       0
# 2019-04-23  1.1259  1.1261  1.1193  1.1259     1.1259       0
# 2019-04-24  1.1224  1.1225  1.1183  1.1224     1.1224       0
# 2019-04-25  1.1157  1.1164  1.1122  1.1153     1.1153       0
# 2019-04-26  1.1137  1.1173  1.1123  1.1137     1.1137       0
# 2019-04-29  1.1149  1.1170  1.1146  1.1150     1.1150       0
# 2019-04-30  1.1184  1.1230  1.1177  1.1185     1.1185       0
#
# [3687 rows x 6 columns]

# %%
from pylab import plt
plt.style.use('seaborn')
# %matplotlib inline

# %%
data = es["Close"]

# %%
data.plot(figsize=(10, 6));

# %%
# The adjusted close accounts for stock splits, so that is what we should graph
plt.plot(gm.index, gm['Adj. Close'])
plt.title('GM Stock Price')
plt.ylabel('Price ($)');
plt.show()
plt.plot(tesla.index, tesla['Adj. Close'], 'r')
plt.title('Tesla Stock Price')
plt.ylabel('Price ($)');
plt.show();
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-31-b12732b4ad5f> in <module>
#       5 quandl.ApiConfig.api_key = 'getyourownkey!'
#       6 # Retrieve TSLA data from Quandl
# ----> 7 tesla = quandl.get('WIKI/TSLA')
#       8 # Retrieve the GM data from Quandl
#       9 gm = quandl.get('WIKI/GM')
#
# C:\ProgramData\Anaconda3\lib\site-packages\quandl\get.py in get(dataset, **kwargs)
#      46         if dataset_args['column_index'] is not None:
#      47             kwargs.update({'column_index': dataset_args['column_index']})
# ---> 48         data = Dataset(dataset_args['code']).data(params=kwargs, handle_column_not_found=True)
#      49     # Array
#      50     elif isinstance(dataset, list):
#
# C:\ProgramData\Anaconda3\lib\site-packages\quandl\model\dataset.py in data(self, **options)
#      45         updated_options = Util.merge_options('params', params, **options)
#      46         try:
# ---> 47             return Data.all(**updated_options)
#      48         except NotFoundError:
#      49             if handle_not_found_error:
#
# C:\ProgramData\Anaconda3\lib\site-packages\quandl\operations\list.py in all(cls, **options)
#      13             options['params'] = {}
#      14         path = Util.constructed_path(cls.list_path(), options['params'])
# ---> 15         r = Connection.request('get', path, **options)
#      16         response_data = r.json()
#      17         Util.convert_to_dates(response_data)
#
# C:\ProgramData\Anaconda3\lib\site-packages\quandl\connection.py in request(cls, http_verb, url, **options)
#      36         abs_url = '%s/%s' % (ApiConfig.api_base, url)
#      37
# ---> 38         return cls.execute_request(http_verb, abs_url, **options)
#      39
#      40     @classmethod
#
# C:\ProgramData\Anaconda3\lib\site-packages\quandl\connection.py in execute_request(cls, http_verb, url, **options)
#      45             response = session.request(method=http_verb, url=url, **options)
#      46             if response.status_code < 200 or response.status_code >= 300:
# ---> 47                 cls.handle_api_error(response)
#      48             else:
#      49                 return response
#
# C:\ProgramData\Anaconda3\lib\site-packages\quandl\connection.py in handle_api_error(cls, resp)
#     109         klass = d_klass.get(code_letter, QuandlError)
#     110
# --> 111         raise klass(message, resp.status_code, resp.text, resp.headers, code)
#
# AuthenticationError: (Status 400) (Quandl Error QEAx01) We could not recognize your API key: getyourownkey!. Please check your API key and try again. You can find your API key under your account settings.
